# %%
#Функция, производящаяя, все действия функции строящей график, кроме самого построения
# и считающая затраченное время
def pi_func_plot_time_measure(deg_max):
    start_time = time.time()
    x = []
    y = []
    y_Fib = []
    y_Trib = []
    y_Tetr = []
    
    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func(x[i]))
        y_Fib.append(Pi_func_Fib(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene(deg_max):
    start_time = time.time()
    x = []
    y = []
    y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func_using_sieve_Eratosphene(x[i]))
        y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene_paralleled(deg_max):
    start_time = time.time()
    x = []
    y = []
    y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene_paralleled(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func_using_sieve_Eratosphene_paralleled(x[i]))
        y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene_paralleled(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена, распараллеленного: {execution_time:.4f} секунд")

    return execution_time

    

    
#Функция, которая строит зависимость времени выполнения построения графика пи-функции
#от степени максимального его аргумента
def plot_execution_time(deg_max):
    deg = []
    ex_time = []
    ex_time_Eratosphene = []
    ex_time_Eratosphene_paralleled = []
    for i in range(1, deg_max + 1):
        #обавляем значение аргумента, несколько раз для равенства количества точек
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        #Добавляем значения времеи выполнения с обычной проверкой на простоту
        ex_t_1 = pi_func_plot_time_measure(i)
        ex_t_2 = pi_func_plot_time_measure(i)
        ex_t_3 = pi_func_plot_time_measure(i)
        ex_t_4 = pi_func_plot_time_measure(i)
        ex_t_5 = pi_func_plot_time_measure(i)
        #print("Время выполнения программы " + str(ex_t) + " секунд")
        #ex_time.append((ex_t_1 + ex_t_2 + ex_t_3 + ex_t_4 + ex_t_5) / 5)
        ex_time.append(ex_t_1)
        ex_time.append(ex_t_2)
        ex_time.append(ex_t_3)
        ex_time.append(ex_t_4)
        ex_time.append(ex_t_5)
        # Добавляем значения времени выполнения с использованием решета Эратосфена
        ex_t_1 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene(i)
        
        ex_time_Eratosphene.append(ex_t_1)
        ex_time_Eratosphene.append(ex_t_2)
        ex_time_Eratosphene.append(ex_t_3)
        ex_time_Eratosphene.append(ex_t_4)
        ex_time_Eratosphene.append(ex_t_5)
        
        # Добавляем значения времени выполнения с использованием решета Эратосфена, распараллеленного
        ex_t_1 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        
        ex_time_Eratosphene_paralleled.append(ex_t_1)
        ex_time_Eratosphene_paralleled.append(ex_t_2)
        ex_time_Eratosphene_paralleled.append(ex_t_3)
        ex_time_Eratosphene_paralleled.append(ex_t_4)
        ex_time_Eratosphene_paralleled.append(ex_t_5)
        
    #i = deg_max + 1
    #deg.append(i)
    #ex_t_1 = pi_func_plot_time_measure(i)
    #ex_time.append(ex_t_1)
    #ex_t_1 = pi_func_plot_time_measure_Eratosphene(i)
    #ex_time_Eratosphene.append(ex_t_1)
    #ex_t_1 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
    #ex_time_Eratosphene_paralleled.append(ex_t_1)
    

    data = pd.DataFrame({
    'deg x': deg,
    'Execution_time': ex_time,
    'Execution_time_Eratosphene': ex_time_Eratosphene,
    'Execution_time_Eratosphene_paralleled': ex_time_Eratosphene_paralleled
        
    })


    plt.figure(figsize=(10, 6))
    '''sns.scatterplot(data=data, x='deg x', y='Execution_time')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene_paralleled')'''
    plt.plot(deg, ex_time, linestyle='--')
    plt.plot(deg, ex_time_Eratosphene)
    plt.plot(deg, ex_time_Eratosphene_paralleled)
    plt.legend(["Перебор делителей", "решето Эратосфена", "параллельный алгоритм"])
    plt.errorbar(deg, ex_time, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
    plt.errorbar(deg, ex_time_Eratosphene, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
    plt.errorbar(deg, ex_time_Eratosphene_paralleled, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
    plt.yscale('log')

    plt.title('Производительность')
    plt.xlabel('Степень максимального аргумента')
    plt.ylabel('Время выполнения')

    plt.show()
    
    return data
        
data = plot_execution_time(3)# Осталось только запустить
# Out:
# Время выполнения: 0.0001 секунд
# Время выполнения: 0.0001 секунд
# Время выполнения: 0.0001 секунд
# Время выполнения: 0.0001 секунд
# Время выполнения: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена: 0.0002 секунд
# Время выполнения с использованием решета Эратосфена: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.5264 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.2139 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.1987 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.2421 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.2243 секунд
# Время выполнения: 0.0021 секунд
# Время выполнения: 0.0026 секунд
# Время выполнения: 0.0021 секунд
# Время выполнения: 0.0020 секунд
# Время выполнения: 0.0023 секунд
# Время выполнения с использованием решета Эратосфена: 0.0059 секунд
# Время выполнения с использованием решета Эратосфена: 0.0048 секунд
# Время выполнения с использованием решета Эратосфена: 0.0050 секунд
# Время выполнения с использованием решета Эратосфена: 0.0040 секунд
# Время выполнения с использованием решета Эратосфена: 0.0043 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 3.5119 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 2.6286 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 3.1401 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 2.4804 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 3.1696 секунд
# Время выполнения: 0.1006 секунд
# Время выполнения: 0.0929 секунд
# Время выполнения: 0.0921 секунд
# Время выполнения: 0.0900 секунд
# Время выполнения: 0.1011 секунд
# Время выполнения с использованием решета Эратосфена: 1.0302 секунд
# Время выполнения с использованием решета Эратосфена: 0.9831 секунд
# Время выполнения с использованием решета Эратосфена: 0.9704 секунд
# Время выполнения с использованием решета Эратосфена: 0.9168 секунд
# Время выполнения с использованием решета Эратосфена: 0.8753 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 49.0145 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 48.0967 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 47.6769 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 48.1845 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 47.2442 секунд

# %%
data.to_excel("/home/denisermakov/Рабочий стол/МИЭМ/профсеминар/data.xlsx")

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(data=data, x='deg x', y='Execution_time')
sns.lineplot(data=data, x='deg x', y='Execution_time_Eratosphene')
sns.lineplot(data=data, x='deg x', y='Execution_time_Eratosphene_paralleled')
plt.legend(["Перебор делителей", "решето Эратосфена", "параллельный алгоритм"])
#plt.errorbar(deg, ex_time, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
#plt.errorbar(deg, ex_time_Eratosphene, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
#plt.errorbar(deg, ex_time_Eratosphene_paralleled, xerr=0, yerr=0.01, fmt='o-', ecolor='red')
plt.yscale('log')

plt.title('Производительность')
plt.xlabel('Степень максимального аргумента')
plt.ylabel('Время выполнения')

plt.show()

# %%
#Функция, производящаяя, все действия функции строящей график, кроме самого построения
# и считающая затраченное время
def pi_func_plot_time_measure(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func(x[i]))
        y_Fib.append(Pi_func_Fib(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func_using_sieve_Eratosphene(x[i]))
        y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene_paralleled(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene_paralleled(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func_using_sieve_Eratosphene_paralleled(x[i]))
        y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene_paralleled(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена, распараллеленного: {execution_time:.4f} секунд")

    return execution_time

    

    
#Функция, которая строит зависимость времени выполнения построения графика пи-функции
#от степени максимального его аргумента
def plot_execution_time(deg_max):
    deg = []
    ex_time = []
    ex_time_Eratosphene = []
    ex_time_Eratosphene_paralleled = []
    for i in range(1, deg_max + 1):
        #обавляем значение аргумента, несколько раз для равенства количества точек
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        #Добавляем значения времеи выполнения с обычной проверкой на простоту
        ex_t_1 = pi_func_plot_time_measure(i)
        ex_t_2 = pi_func_plot_time_measure(i)
        ex_t_3 = pi_func_plot_time_measure(i)
        ex_t_4 = pi_func_plot_time_measure(i)
        ex_t_5 = pi_func_plot_time_measure(i)
        #print("Время выполнения программы " + str(ex_t) + " секунд")
        #ex_time.append((ex_t_1 + ex_t_2 + ex_t_3 + ex_t_4 + ex_t_5) / 5)
        ex_time.append(ex_t_1)
        ex_time.append(ex_t_2)
        ex_time.append(ex_t_3)
        ex_time.append(ex_t_4)
        ex_time.append(ex_t_5)
        # Добавляем значения времени выполнения с использованием решета Эратосфена
        ex_t_1 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene(i)
        
        ex_time_Eratosphene.append(ex_t_1)
        ex_time_Eratosphene.append(ex_t_2)
        ex_time_Eratosphene.append(ex_t_3)
        ex_time_Eratosphene.append(ex_t_4)
        ex_time_Eratosphene.append(ex_t_5)
        
        # Добавляем значения времени выполнения с использованием решета Эратосфена, распараллеленного
        ex_t_1 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        
        ex_time_Eratosphene_paralleled.append(ex_t_1)
        ex_time_Eratosphene_paralleled.append(ex_t_2)
        ex_time_Eratosphene_paralleled.append(ex_t_3)
        ex_time_Eratosphene_paralleled.append(ex_t_4)
        ex_time_Eratosphene_paralleled.append(ex_t_5)

    data = pd.DataFrame({
    'deg x': deg,
    'Execution_time': ex_time,
    'Execution_time_Eratosphene': ex_time_Eratosphene,
    'Execution_time_Eratosphene_paralleled': ex_time_Eratosphene_paralleled
        
    })

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=data, x='deg x', y='Execution_time')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene_paralleled')

    plt.yscale('log')
    
    plt.legend(["Перебор делителей", "решето Эратосфена", "параллельный алгоритм"])

    plt.title('Производительность')
    plt.xlabel('Степень максимального аргумента')
    plt.ylabel('Время выполнения')

    plt.show()
    return data
        
data = plot_execution_time(2)
# Out:
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0001 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0837 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0784 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0700 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0677 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0629 секунд
# Время выполнения: 0.0003 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения с использованием решета Эратосфена: 0.0009 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.9960 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.0303 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.9690 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.9911 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.0050 секунд

# %%
#Функция, производящаяя, все действия функции строящей график, кроме самого построения
# и считающая затраченное время
def pi_func_plot_time_measure(deg_max):
    start_time = time.time()
    x = []
    y = []
    #y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func(x[i]))
        #y_Fib.append(Pi_func_Fib(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene(deg_max):
    start_time = time.time()
    x = []
    y = []
    #y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func_using_sieve_Eratosphene(x[i]))
        #y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene_paralleled(deg_max):
    start_time = time.time()
    x = []
    y = []
    #y_Fib = []

    #Аргументы генерируются не как степени десятки, а как простые числа Фибоначчи, на которых происходят скачки
    #x = Fib_numbers_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene_paralleled(range(2, 10**deg_max))
    for i in range(len(x)):
        y.append(Pi_func_using_sieve_Eratosphene_paralleled(x[i]))
        #y_Fib.append(Pi_func_Fib_using_sieve_Eratosphene_paralleled(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена, распараллеленного: {execution_time:.4f} секунд")

    return execution_time

    

    
#Функция, которая строит зависимость времени выполнения построения графика пи-функции
#от степени максимального его аргумента
def plot_execution_time(deg_max):
    deg = []
    ex_time = []
    ex_time_Eratosphene = []
    ex_time_Eratosphene_paralleled = []
    for i in range(1, deg_max + 1):
        #обавляем значение аргумента, несколько раз для равенства количества точек
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        #Добавляем значения времеи выполнения с обычной проверкой на простоту
        ex_t_1 = pi_func_plot_time_measure(i)
        ex_t_2 = pi_func_plot_time_measure(i)
        ex_t_3 = pi_func_plot_time_measure(i)
        ex_t_4 = pi_func_plot_time_measure(i)
        ex_t_5 = pi_func_plot_time_measure(i)
        #print("Время выполнения программы " + str(ex_t) + " секунд")
        #ex_time.append((ex_t_1 + ex_t_2 + ex_t_3 + ex_t_4 + ex_t_5) / 5)
        ex_time.append(ex_t_1)
        ex_time.append(ex_t_2)
        ex_time.append(ex_t_3)
        ex_time.append(ex_t_4)
        ex_time.append(ex_t_5)
        # Добавляем значения времени выполнения с использованием решета Эратосфена
        ex_t_1 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene(i)
        
        ex_time_Eratosphene.append(ex_t_1)
        ex_time_Eratosphene.append(ex_t_2)
        ex_time_Eratosphene.append(ex_t_3)
        ex_time_Eratosphene.append(ex_t_4)
        ex_time_Eratosphene.append(ex_t_5)
        
        # Добавляем значения времени выполнения с использованием решета Эратосфена, распараллеленного
        ex_t_1 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        
        ex_time_Eratosphene_paralleled.append(ex_t_1)
        ex_time_Eratosphene_paralleled.append(ex_t_2)
        ex_time_Eratosphene_paralleled.append(ex_t_3)
        ex_time_Eratosphene_paralleled.append(ex_t_4)
        ex_time_Eratosphene_paralleled.append(ex_t_5)

    data = pd.DataFrame({
    'deg x': deg,
    'Execution_time': ex_time,
    'Execution_time_Eratosphene': ex_time_Eratosphene,
    'Execution_time_Eratosphene_paralleled': ex_time_Eratosphene_paralleled
        
    })

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=data, x='deg x', y='Execution_time')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene_paralleled')

    plt.yscale('log')

    plt.legend(["Перебор делителей", "решето Эратосфена", "параллельный алгоритм"])

    plt.title('Производительность')
    plt.xlabel('Степень максимального аргумента')
    plt.ylabel('Время выполнения')

    plt.show()
    
    return data
        
data = plot_execution_time(2)
# Out:
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.1064 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0814 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.2352 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.1385 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.1219 секунд
# Время выполнения: 0.0009 секунд
# Время выполнения: 0.0011 секунд
# Время выполнения: 0.0010 секунд
# Время выполнения: 0.0012 секунд
# Время выполнения: 0.0022 секунд
# Время выполнения с использованием решета Эратосфена: 0.0015 секунд
# Время выполнения с использованием решета Эратосфена: 0.0019 секунд
# Время выполнения с использованием решета Эратосфена: 0.0015 секунд
# Время выполнения с использованием решета Эратосфена: 0.0017 секунд
# Время выполнения с использованием решета Эратосфена: 0.0017 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.4357 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.0414 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.0852 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.1364 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.1411 секунд

# %%
#Функция, производящаяя, все действия функции строящей график, кроме самого построения
# и считающая затраченное время
def pi_func_plot_time_measure(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Tetr = []

    #Аргументы генерируются не как степени десятки, а как простые Числа Тетрабоначчи, на которых происходят скачки
    #x = Tetrab_num_fill(10**deg_max, x)
    x = cut_composites(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func(x[i]))
        y_Tetr.append(Pi_func_Tetr(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Tetr = []

    #Аргументы генерируются не как степени десятки, а как простые Числа Тетрабоначчи, на которых происходят скачки
    #x = Tetrab_num_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func_using_sieve_Eratosphene(x[i]))
        y_Tetr.append(Pi_func_Tetr_using_sieve_Eratosphene(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена: {execution_time:.4f} секунд")

    return execution_time

def pi_func_plot_time_measure_Eratosphene_paralleled(deg_max):
    start_time = time.time()
    x = []
    #y = []
    y_Tetr = []

    #Аргументы генерируются не как степени десятки, а как простые Числа Тетрабоначчи, на которых происходят скачки
    #x = Tetrab_num_fill(10**deg_max, x)
    x = cut_composites_by_sieve_Eratosphene_paralleled(range(2, 10**deg_max))
    for i in range(len(x)):
        #y.append(Pi_func_using_sieve_Eratosphene_paralleled(x[i]))
        y_Tetr.append(Pi_func_Tetr_using_sieve_Eratosphene_paralleled(x[i]))

    end_time = time.time()  

    execution_time = end_time - start_time
    print(f"Время выполнения с использованием решета Эратосфена, распараллеленного: {execution_time:.4f} секунд")

    return execution_time

    

    
#Функция, которая строит зависимость времени выполнения построения графика пи-функции
#от степени максимального его аргумента
def plot_execution_time(deg_max):
    deg = []
    ex_time = []
    ex_time_Eratosphene = []
    ex_time_Eratosphene_paralleled = []
    for i in range(1, deg_max + 1):
        #обавляем значение аргумента, несколько раз для равенства количества точек
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        deg.append(i)
        #Добавляем значения времени выполнения с обычной проверкой на простоту
        ex_t_1 = pi_func_plot_time_measure(i)
        ex_t_2 = pi_func_plot_time_measure(i)
        ex_t_3 = pi_func_plot_time_measure(i)
        ex_t_4 = pi_func_plot_time_measure(i)
        ex_t_5 = pi_func_plot_time_measure(i)
        #print("Время выполнения программы " + str(ex_t) + " секунд")
        #ex_time.append((ex_t_1 + ex_t_2 + ex_t_3 + ex_t_4 + ex_t_5) / 5)
        ex_time.append(ex_t_1)
        ex_time.append(ex_t_2)
        ex_time.append(ex_t_3)
        ex_time.append(ex_t_4)
        ex_time.append(ex_t_5)
        # Добавляем значения времени выполнения с использованием решета Эратосфена
        ex_t_1 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene(i)
        
        ex_time_Eratosphene.append(ex_t_1)
        ex_time_Eratosphene.append(ex_t_2)
        ex_time_Eratosphene.append(ex_t_3)
        ex_time_Eratosphene.append(ex_t_4)
        ex_time_Eratosphene.append(ex_t_5)
        
        # Добавляем значения времени выполнения с использованием решета Эратосфена, распараллеленного
        ex_t_1 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_2 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_3 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_4 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        ex_t_5 = pi_func_plot_time_measure_Eratosphene_paralleled(i)
        
        ex_time_Eratosphene_paralleled.append(ex_t_1)
        ex_time_Eratosphene_paralleled.append(ex_t_2)
        ex_time_Eratosphene_paralleled.append(ex_t_3)
        ex_time_Eratosphene_paralleled.append(ex_t_4)
        ex_time_Eratosphene_paralleled.append(ex_t_5)

    data = pd.DataFrame({
    'deg x': deg,
    'Execution_time': ex_time,
    'Execution_time_Eratosphene': ex_time_Eratosphene,
    'Execution_time_Eratosphene_paralleled': ex_time_Eratosphene_paralleled
        
    })

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=data, x='deg x', y='Execution_time')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene')
    sns.scatterplot(data=data, x='deg x', y='Execution_time_Eratosphene_paralleled')

    plt.yscale('log')
    
    plt.legend(["Перебор делителей", "решето Эратосфена", "параллельный алгоритм"])

    plt.title('Производительность')
    plt.xlabel('Степень максимального аргумента')
    plt.ylabel('Время выполнения')

    plt.show()
    return data
        
data = plot_execution_time(2)
# Out:
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена: 0.0000 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0670 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0685 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0621 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0545 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.0597 секунд
# Время выполнения: 0.0003 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения: 0.0002 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена: 0.0008 секунд
# Время выполнения с использованием решета Эратосфена: 0.0007 секунд
# Время выполнения с использованием решета Эратосфена: 0.0007 секунд
# Время выполнения с использованием решета Эратосфена: 0.0007 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.9780 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.3376 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 1.6865 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.9500 секунд
# Время выполнения с использованием решета Эратосфена, распараллеленного: 0.8751 секунд
